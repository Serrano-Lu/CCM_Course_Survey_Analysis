# %%
import pandas as pd

# %%
# Load the 2023 dataset 
df_2023 = pd.read_csv('Non-Majors Survey Results - Fall 2023.csv')

# %%
# Confirm loading by printing the first few rows
df_2023.head()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0   2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1   2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2  2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3  2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4  2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                 No
# ...

# %%
# Show the column names in the dataset
df_2023.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
# Check the shape (number of rows and columns) of the dataset
df_2023.shape
# Out:
# (105, 96)

# %%
# Check the data types of each column
df_2023.dtypes
# Out:
# Timestamp                                                                                                                                    object
# Which course are you currently enrolled in?                                                                                                  object
# How did you hear about County College of Morris? [CCM Web site]                                                                              object
# How did you hear about County College of Morris? [Social Media]                                                                              object
# How did you hear about County College of Morris? [Community Event]                                                                           object
#                                                                                                                                               ...
# ...

# %%
# Display the first 5 rows
df_2023.head()
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 0   2023/09/05 9:36:31 PM EST         CMP 101 Computer Information Literacy
# 1   2023/09/05 9:42:31 PM EST         CMP 101 Computer Information Literacy
# 2  2023/09/05 10:00:08 PM EST         CMP 101 Computer Information Literacy
# 3  2023/09/05 11:12:17 PM EST  CMP 126 Computer Technology and Applications
# 4  2023/09/05 11:56:29 PM EST  CMP 126 Computer Technology and Applications
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                 No
# ...

# %%
# Display the last 5 rows
df_2023.tail()
# Out:
#                       Timestamp  Which course are you currently enrolled in?  \
# 100   2023/09/19 6:04:34 PM EST  CMP 135 Computer Concepts with Applications
# 101   2023/09/19 6:05:55 PM EST        CMP 101 Computer Information Literacy
# 102   2023/09/19 6:07:54 PM EST  CMP 135 Computer Concepts with Applications
# 103   2023/09/19 6:08:11 PM EST  CMP 135 Computer Concepts with Applications
# 104  2023/09/19 10:44:14 PM EST  CMP 135 Computer Concepts with Applications
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 100                                                 No
# 101                                                Yes
# 102                                                Yes
# 103                                                Yes
# 104                                       Don't recall
#
#     How did you hear about County College of Morris? [Social Media]  \
# 100                                                 No
# ...

# %%
# Display a random sample of 5 rows
df_2023.sample(5)
# Out:
#                     Timestamp   Which course are you currently enrolled in?  \
# 98  2023/09/19 6:03:41 PM EST         CMP 101 Computer Information Literacy
# 22  2023/09/07 9:26:29 AM EST   CMP 135 Computer Concepts with Applications
# 51  2023/09/12 5:52:37 PM EST  CMP 126 Computer Technology and Applications
# 80  2023/09/19 9:42:50 AM EST   CMP 135 Computer Concepts with Applications
# 43  2023/09/11 7:01:16 PM EST         CMP 101 Computer Information Literacy
#
#    How did you hear about County College of Morris? [CCM Web site]  \
# 98                                                 No
# 22                                                Yes
# 51                                                 No
# 80                                                 No
# 43                                                Yes
#
#    How did you hear about County College of Morris? [Social Media]  \
# 98                                                 No
# ...

# %%
# Display a summary of the dataset, including the count of non-null values
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 96 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        105 non-null    object
# ...

# %%
# Rename columns to lowercase and replace spaces with underscores
df_2023.columns = df_2023.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Confirm the changes by displaying the new column names
df_2023.columns
# Out:
# Index(['timestamp', 'which_course_are_you_currently_enrolled_in?',
#        'how_did_you_hear_about_county_college_of_morris?_[ccm_web_site]',
#        'how_did_you_hear_about_county_college_of_morris?_[social_media]',
#        'how_did_you_hear_about_county_college_of_morris?_[community_event]',
#        'how_did_you_hear_about_county_college_of_morris?_[family_member_or_friend]',
#        'how_did_you_hear_about_county_college_of_morris?_[current_ccm_student]',
#        'how_did_you_hear_about_county_college_of_morris?_[ccm_alumni]',
#        'how_did_you_hear_about_county_college_of_morris?_[high_school_teacher]',
#        'how_did_you_hear_about_county_college_of_morris?_[high_school_counselor]',
#        'how_did_you_hear_about_county_college_of_morris?_[in-app_advertisement]',
#        'how_did_you_hear_about_county_college_of_morris?_[employer]',
#        'how_did_you_hear_about_county_college_of_morris?_[billboard]',
# ...

# %%
# Clean and condense 'Race/Ethnicity' column
race_mapping = {
    'White/Caucasian': 'White',
    'Black/African American': 'Black',
    'Hispanic or Latino': 'Hispanic',
    'Asian': 'Asian',
    'Multi-Racial': 'Multiracial',
    'Hispanic or Latino;White/Caucasian': 'Multiracial',
}

# %%
# Apply the mapping to the 'Race/Ethnicity' column
df_2023['race/ethnicity'] = df_2023['race/ethnicity'].replace(race_mapping)

# %%
# Verify the changes
df_2023['race/ethnicity'].unique()
# Out:
# array(['Hispanic', 'White', 'Asian', 'Multiracial', 'Choose not to reply',
#        'Hispanic or Latino;Multi-Racial', 'Black',
#        'Hispanic or Latino;Black/African American',
#        'Hispanic or Latino;Asian;White/Caucasian;Multi-Racial',
#        'Asian;White/Caucasian', 'Black/African American;White/Caucasian',
#        'Asian;White/Caucasian;Multi-Racial'], dtype=object)

# %%
# Clean and condense 'Major' column 
major_mapping = {
    # Engineering majors
    'Mechanical Engineering': 'Engineering',
    'Electrical Engineering': 'Engineering',
    'Civil Engineering': 'Engineering',
    'Chemical Engineering': 'Engineering',
    'Biomedical Engineering': 'Engineering',
    
    # Computing majors
    'Computer Science': 'Computing',
    'Information Technology': 'Computing',
    'Software Development': 'Computing',
    'Cybersecurity': 'Computing',
    
    # Liberal Arts majors
    'Liberal Arts and Sciences': 'Liberal Arts',
    'Liberal Arts': 'Liberal Arts',
    'Humanities': 'Liberal Arts',
    'Social Sciences': 'Liberal Arts',
    
    # Health Sciences majors
    'Nursing': 'Health Sciences',
    'Radiography': 'Health Sciences',
    'Public Health': 'Health Sciences',
    
    # Business majors
    'Business Administration': 'Business',
    'Marketing': 'Business',
    'Finance': 'Business',
    'Accounting': 'Business',
    
    # Musical Arts majors
    'Music Performance': 'Musical Arts',
    'Musical Theatre': 'Musical Arts',
    'Music Technology': 'Musical Arts',
    
    # Psychology majors
    'Psychology': 'Psychology',
    'Counseling Psychology': 'Psychology',
    'Clinical Psychology': 'Psychology',
    'psychology': 'Psychology',
    'Educational Psychology': 'Psychology'
}

# %%
# Apply the mapping to the 'Major' column
df_2023['what_degree_program_are_you_currently_enrolled_in?'] = df_2023['what_degree_program_are_you_currently_enrolled_in?'].replace(major_mapping)

# %%
# Verify the changes
df_2023['what_degree_program_are_you_currently_enrolled_in?'].unique()
# Out:
# array(['Health Sciences', 'Early Childhood Education', 'Liberal Arts',
#        'Criminal Justice', 'psychology , liberal arts',
#        'Child and Family Studies', 'Exercise Science',
#        'Theatre Technology', 'Human Resources/ Psychology',
#        'Broadcasting Arts and Technology', 'Communication', 'Psychology',
#        'World Language', 'Musical Arts', 'Music recording',
#        'Fire Science Technologies '], dtype=object)

# %%
# Clean and standardize 'gender' column
gender_mapping = {
    'male': 'Male',
    'female': 'Female',
    'M': 'Male',
    'F': 'Female',
   
}

# %%
# Apply the mapping to the 'gender' column
df_2023['gender'] = df_2023['gender'].replace(gender_mapping)

# %%
# Verify the changes
df_2023['gender'].unique()
# Out:
# array(['Woman', 'Man', nan, 'Prefer not to say', 'Non-binary'],
#       dtype=object)

# %%
# Review unique values in the 'age' column
df_2023['age'].unique()
# Out:
# array(['18 and younger', '19-20', '35-64', '25-34', '21-24'], dtype=object)

# %%
# Review unique values in the interest column
df_2023['on_a_scale_of_1_to_5,_with_1_being_not_at_all_interested_and_5_being_extremely_interested,_how_interested_are_you_taking_more_courses_in_computer_science,_information_technology_or_game_development?'].unique()
# Out:
# array([1, 3, 2, 4, 5], dtype=int64)

# %%
# Review unique values for communication channels
df_2023['how_did_you_hear_about_county_college_of_morris?_[ccm_web_site]'].unique()
# Out:
# array(['Yes', 'No', "Don't recall"], dtype=object)

# %%
# Save the cleaned dataset to a new CSV file

# Save the cleaned 2023 dataset
df_2023.to_csv('cleaned_2023_dataset.csv', index=False)

print("Cleaned dataset has been saved as 'cleaned_2023_dataset.csv'.")
# Out:
# Cleaned dataset has been saved as 'cleaned_2023_dataset.csv'.
